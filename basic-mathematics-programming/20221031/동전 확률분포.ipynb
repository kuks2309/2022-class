# %%
import sys
import math
print(sys.version)

# %%
# !python  --version

# %%
def permutations_count(n, r):
    return math.factorial(n) // math.factorial(n - r)

print(permutations_count(4, 2))

# %%
def combination_count(n,r):
    return math.factorial(n)//(math.factorial(n - r)*math.factorial(r)  )

print(combination_count(4, 2))

# %%
print("동전 한개를 n 번 던저셔 뒷면이 나올 확률은 ? \n")

# %%
n=0
print("던지는 횟수를 입력하세요");
n = int(input())
type(n)

# %%
total_n = pow(2,n)
print(total_n)

# %%
avg = 0.0
var = 0.0
for x in range(n+1):
    P =  combination_count(n,x)/ total_n 
    avg += x * P
    print("P(",x, ") =", P)
print("average = ", avg) 

for x in range(n+1):
    P =  combination_count(n,x)/ total_n 
    var = (x - avg)* (x - avg) * P
print("variance = ", var)
